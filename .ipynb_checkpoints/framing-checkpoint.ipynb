# %%
import pickle

# %%
with open('test.p','rb') as fopen:
    h264 = pickle.load(fopen)

# %%
for i in range(len(h264)):
    print(len(h264[i]))
# Out:
# 13
# 8
# 1458
# 1458
# 1458
# 1458
# 1458
# 734
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 388
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 612
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 576
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 642
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1185
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1235
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1394
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 817
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 743
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 840
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 891
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 765
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 898
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 798
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# 1458
# ...

# %%
h264[0]
# Out:
# b'\x00\x00\x00\x01gM@(\x95\xa0<\x05\xb9'

# %%
h264[1]
# Out:
# b'\x00\x00\x00\x01h\xee8\x80'

# %%
with open('temp.h264','wb') as fopen:
    fopen.write(b''.join(h264[:16]))

# %%
len(h264[16])
# Out:
# 388
